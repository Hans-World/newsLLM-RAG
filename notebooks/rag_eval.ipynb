# %% [markdown]
# # Basic RAG Evaluation
#
# Evaluates the retrieval and generation quality of the news RAG pipeline using MediaTek's dataset from hugging Face: https://huggingface.co/datasets/MediaTek-Research/TCEval-v2

# %%
import sys
sys.path.insert(0, "..")  # make project root importable

from dotenv import load_dotenv
load_dotenv("../.env")
# Out:
# True

# %%
# Initiate Embedders
from indexing import E5Embedder, BM25SparseEmbedder
dense_embedder = E5Embedder()
sparse_embedder = BM25SparseEmbedder()

# %%
# Run pipeline and collect sample
from generate import run_pipeline

samples = []

for question in questions: 
    print(f"Running")
    
    llm_response, retrieved_chunks = run_pipeline(
        query=question, 
        dense_embedder=dense_embedder, 
        sparse_embedder=sparse_embedder,
        top_k=5,
        isQueryRewrite=False)
    
    answer = "".join(llm_response)
    contexts = [rc.chunk.text for rc in retrieved_chunks]
    
    samples.append({
        "user_input": question,
        "llm_response": answer,
        "retrieved_contexts": contexts,
    })
    
    print(f"  → collected ({len(contexts)} chunks)\n")
print("Done")
# Out:
# Running
# --- [User Query] ---
# [Original] : 台灣最近有哪些重要的能源政策新聞？
# ---------------------------------------------------------------------------
# UnexpectedResponse                        Traceback (most recent call last)
# Cell In[8], line 9
#       6 for question in questions:
#       7     print(f"Running")
# ----> 9     llm_response, retrieved_chunks = run_pipeline(
#      10         query=question,
#      11         dense_embedder=dense_embedder,
#      12         sparse_embedder=sparse_embedder,
#      13         top_k=5,
#      14         isQueryRewrite=False)
#      16     answer = "".join(llm_response)
#      17     contexts = [rc.chunk.text for rc in retrieved_chunks]
#
# File ~/newsLLM-RAG/notebooks/../generate.py:43, in run_pipeline(query, dense_embedder, sparse_embedder, history, top_k, isQueryRewrite)
#      40 sparse_vector = sparse_embedder.encode_query(query)
#      42 # Stage 6: Retrieve
# ...
